# %% [markdown]
# # Airline Passenger Satisfaction
# ## Classification

# %% [markdown]
# Gender: Gender of the passengers (Female, Male)
#
# Customer Type: The customer type (Loyal customer, disloyal customer)
#
# Age: The actual age of the passengers
#
# Type of Travel: Purpose of the flight of the passengers (Personal Travel, Business Travel)
#
# Class: Travel class in the plane of the passengers (Business, Eco, Eco Plus)
#
# Flight distance: The flight distance of this journey
#
# Inflight wifi service: Satisfaction level of the inflight wifi service (0:Not Applicable;1-5)
#
# Departure/Arrival time convenient: Satisfaction level of Departure/Arrival time convenient
#
# Ease of Online booking: Satisfaction level of online booking
#
# Gate location: Satisfaction level of Gate location
#
# Food and drink: Satisfaction level of Food and drink
#
# Online boarding: Satisfaction level of online boarding
#
# Seat comfort: Satisfaction level of Seat comfort
#
# Inflight entertainment: Satisfaction level of inflight entertainment
#
# On-board service: Satisfaction level of On-board service
#
# Leg room service: Satisfaction level of Leg room service
#
# Baggage handling: Satisfaction level of baggage handling
#
# Check-in service: Satisfaction level of Check-in service
#
# Inflight service: Satisfaction level of inflight service
#
# Cleanliness: Satisfaction level of Cleanliness
#
# Departure Delay in Minutes: Minutes delayed when departure
#
# Arrival Delay in Minutes: Minutes delayed when Arrival
#
# Satisfaction: Airline satisfaction level(Satisfaction, neutral or dissatisfaction)

# %% [markdown]
# ### Dataset je već podeljen na trening i test set !

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
# %matplotlib inline
from keras import models
import keras
from keras import layers
from sklearn.model_selection import train_test_split
import pydot
from keras.utils.vis_utils import plot_model
import keras.backend as K

# %%
data=pd.read_csv('train.csv')
dataTest=pd.read_csv('test.csv')

# %%
data.head(5)
# Out:
#    n      id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0  0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1  1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  2  110028  Female     Loyal Customer   26  Business travel  Business
# 3  3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              460                      3                                  4
# 1              235                      3                                  2
# 2             1142                      2                                  2
# 3              562                      2                                  5
# 4              214                      3                                  3
#
#    ...  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
dataTest.head(5)
# Out:
#    n     id  Gender      Customer Type  Age   Type of Travel     Class  \
# 0  0  19556  Female     Loyal Customer   52  Business travel       Eco
# 1  1  90035  Female     Loyal Customer   36  Business travel  Business
# 2  2  12360    Male  disloyal Customer   20  Business travel       Eco
# 3  3  77959    Male     Loyal Customer   44  Business travel  Business
# 4  4  36875  Female     Loyal Customer   49  Business travel       Eco
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0              160                      5                                  4
# 1             2863                      1                                  1
# 2              192                      2                                  0
# 3             3377                      0                                  0
# 4             1182                      2                                  3
#
#    ...  Inflight entertainment  On-board service  Leg room service  \
# ...

# %%
data.shape
# Out:
# (103904, 25)

# %%
dataTest.shape
# Out:
# (25976, 25)

# %%
data.isnull().sum()/data.shape[0]
# Out:
# n                                    0.000000
# id                                   0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.000000
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.000000
# Inflight wifi service                0.000000
# Departure/Arrival time convenient    0.000000
# Ease of Online booking               0.000000
# Gate location                        0.000000
# Food and drink                       0.000000
# Online boarding                      0.000000
# Seat comfort                         0.000000
# Inflight entertainment               0.000000
# On-board service                     0.000000
# Leg room service                     0.000000
# Baggage handling                     0.000000
# Checkin service                      0.000000
# ...

# %% [markdown]
# Procentualni odnos između klasa

# %%
print("Unique values for satisfaction:",data["satisfaction"].unique())
print("\nPercentage of distribution for satisfaction-")
print(data["satisfaction"].value_counts()/data.shape[0])
# Out:
# Unique values for satisfaction: ['neutral or dissatisfied' 'satisfied']
#
# Percentage of distribution for satisfaction-
# neutral or dissatisfied    0.566667
# satisfied                  0.433333
# Name: satisfaction, dtype: float64

# %% [markdown]
# Različiti tipovi podataka

# %%
print("Distinct DataTypes:",list(data.dtypes.unique()))
# Out:
# Distinct DataTypes: [dtype('int64'), dtype('O'), dtype('float64')]

# %%
categorical=[]
for col in data:
    if(data[col].dtype=='O'):
        categorical.append(col)
categorical
# Out:
# ['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction']

# %%
for column in categorical:
 print(column+" column has :",str(len(data[column].
unique()))+" distinct values")
# Out:
# Gender column has : 2 distinct values
# Customer Type column has : 2 distinct values
# Type of Travel column has : 2 distinct values
# Class column has : 3 distinct values
# satisfaction column has : 2 distinct values

# %%
data=data.drop(columns=['n','id'])
data.shape
# Out:
# (103904, 23)

# %%
dataTest=dataTest.drop(columns=['n','id'])
dataTest.shape
# Out:
# (25976, 23)

# %%
def showData(data):
    for col in data:
        if(col in categorical):
            sns.countplot(col, data=data)
        else:
            ax=sns.distplot(data[[col]],hist=False,color='pink')
            ax.set(xlabel=col)
        plt.show()

# %%
showData(data)
# Out:
# c:\users\joks\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# c:\users\joks\appdata\local\programs\python\python38\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
def nominalToNumeric(data):
    le = LabelEncoder()
    for col in categorical:
        le.fit(data[col])
        data[col]=le.transform(data[col])
    return data

# %%
data=nominalToNumeric(data)
data.head(5)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       1              0   13               1      2              460
# 1       1              1   25               0      0              235
# 2       0              0   26               0      0             1142
# 3       0              0   25               0      0              562
# 4       1              0   61               0      0              214
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      3                                  4
# 1                      3                                  2
# 2                      2                                  2
# 3                      2                                  5
# 4                      3                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              1  ...                       5
# ...

# %%
dataTest=nominalToNumeric(dataTest)
dataTest.head(5)
# Out:
#    Gender  Customer Type  Age  Type of Travel  Class  Flight Distance  \
# 0       0              0   52               0      1              160
# 1       0              0   36               0      0             2863
# 2       1              1   20               0      1              192
# 3       1              0   44               0      0             3377
# 4       0              0   49               0      1             1182
#
#    Inflight wifi service  Departure/Arrival time convenient  \
# 0                      5                                  4
# 1                      1                                  1
# 2                      2                                  0
# 3                      0                                  0
# 4                      2                                  3
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# 0                       3              4  ...                       5
# ...

# %%
data=data.dropna(axis=0)
data.shape
# Out:
# (103594, 23)

# %%
dataTest=dataTest.dropna(axis=0)
dataTest.shape
# Out:
# (25893, 23)

# %% [markdown]
# ### Standard scaler

# %%
def StandardScale(data):
    scale=StandardScaler()
    datapom=pd.DataFrame()
    clas = data['satisfaction']
    datapom = data.loc[:, data.columns != 'satisfaction']
    datapom = pd.DataFrame(scale.fit_transform(datapom.values), columns=datapom.columns, index=data.index)
    datapom['satisfaction'] = clas
    return datapom

# %%
dtestScaled=StandardScale(dataTest)
dtestScaled.head(5)
# Out:
#      Gender  Customer Type       Age  Type of Travel     Class  \
# 0 -0.986154      -0.475938  0.817898         -0.6634  0.652895
# 1 -0.986154      -0.475938 -0.239329         -0.6634 -0.950273
# 2  1.014041       2.101114 -1.296556         -0.6634  0.652895
# 3  1.014041      -0.475938  0.289285         -0.6634 -0.950273
# 4 -0.986154      -0.475938  0.619668         -0.6634  0.652895
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0        -1.035195               1.705489                           0.622058
# 1         1.671574              -1.291472                          -1.334964
# 2        -1.003150              -0.542232                          -1.987305
# 3         2.186291              -2.040712                          -1.987305
# 4        -0.011770              -0.542232                          -0.030283
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
dtrainScaled=StandardScale(data)
dtrainScaled.head(5)
# Out:
#      Gender  Customer Type       Age  Type of Travel     Class  \
# 0  1.015154      -0.472883 -1.745542        1.491414  2.265027
# 1  1.015154       2.114687 -0.951526       -0.670505 -0.956789
# 2 -0.985072      -0.472883 -0.885358       -0.670505 -0.956789
# 3 -0.985072      -0.472883 -0.951526       -0.670505 -0.956789
# 4  1.015154      -0.472883  1.430521       -0.670505 -0.956789
#
#    Flight Distance  Inflight wifi service  Departure/Arrival time convenient  \
# 0        -0.731305               0.203521                           0.616249
# 1        -0.956916               0.203521                          -0.695032
# 2        -0.047454              -0.549571                          -0.695032
# 3        -0.629028              -0.549571                           1.271890
# 4        -0.977973               0.203521                          -0.039391
#
#    Ease of Online booking  Gate location  ...  Inflight entertainment  \
# ...

# %%
X_train=dtrainScaled.loc[:,dtrainScaled.columns!='satisfaction']
Y_train=pd.DataFrame()
Y_train['satisfaction']=dtrainScaled['satisfaction']
X_train,X_val,Y_train,Y_val=train_test_split(X_train,
Y_train, test_size=0.1, random_state=2018)
X_test=dtestScaled.loc[:,dtestScaled.columns!='satisfaction']
Y_test=pd.DataFrame()
Y_test['satisfaction']=dtestScaled['satisfaction']

# %% [markdown]
# ### Neuronska mreža 22-25-25-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name="first_hidden"))
network.add(layers.Dense(units=25, activation="relu",name="second_hidden"))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 4s 2ms/step - loss: 0.3233 - accuracy: 0.8700 - val_loss: 0.1841 - val_accuracy: 0.9241
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1683 - accuracy: 0.9317 - val_loss: 0.1591 - val_accuracy: 0.9355
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1471 - accuracy: 0.9405 - val_loss: 0.1446 - val_accuracy: 0.9397
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1358 - accuracy: 0.9449 - val_loss: 0.1373 - val_accuracy: 0.9435
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1278 - accuracy: 0.9497 - val_loss: 0.1287 - val_accuracy: 0.9456
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1183 - accuracy: 0.9531 - val_loss: 0.1245 - val_accuracy: 0.9458
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 810us/step - loss: 0.1132 - accuracy: 0.9501
# Metric  loss : 0.11
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
 batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-25-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name='first'))
network.add(layers.Dense(units=1, activation="sigmoid",name='output'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.3478 - accuracy: 0.8521 - val_loss: 0.1989 - val_accuracy: 0.9204
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1827 - accuracy: 0.9283 - val_loss: 0.1773 - val_accuracy: 0.9278
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1671 - accuracy: 0.9331 - val_loss: 0.1680 - val_accuracy: 0.9303
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1543 - accuracy: 0.9401 - val_loss: 0.1596 - val_accuracy: 0.9315
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1508 - accuracy: 0.9397 - val_loss: 0.1526 - val_accuracy: 0.9360
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1465 - accuracy: 0.9419 - val_loss: 0.1475 - val_accuracy: 0.9373
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 802us/step - loss: 0.1238 - accuracy: 0.9498
# Metric  loss : 0.12
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
 batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-25-30-30-25-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=30, activation="relu",name='second_hidden'))
network.add(layers.Dense(units=30, activation="relu",name='third_hidden'))
network.add(layers.Dense(units=25, activation="relu",name='fourth_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 3s 1ms/step - loss: 0.2908 - accuracy: 0.8847 - val_loss: 0.1722 - val_accuracy: 0.9312
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1575 - accuracy: 0.9370 - val_loss: 0.1482 - val_accuracy: 0.9409
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1341 - accuracy: 0.9453 - val_loss: 0.1340 - val_accuracy: 0.9432
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1236 - accuracy: 0.9484 - val_loss: 0.1281 - val_accuracy: 0.9468
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1166 - accuracy: 0.9518 - val_loss: 0.1249 - val_accuracy: 0.9481
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1114 - accuracy: 0.9549 - val_loss: 0.1223 - val_accuracy: 0.9504
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 842us/step - loss: 0.1081 - accuracy: 0.9559
# Metric  loss : 0.11
# Metric  accuracy : 0.96

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
 batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-100-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=100, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.2859 - accuracy: 0.8887 - val_loss: 0.1767 - val_accuracy: 0.9284
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1646 - accuracy: 0.9344 - val_loss: 0.1616 - val_accuracy: 0.9338
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1477 - accuracy: 0.9411 - val_loss: 0.1475 - val_accuracy: 0.9375
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1374 - accuracy: 0.9455 - val_loss: 0.1411 - val_accuracy: 0.9405
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1314 - accuracy: 0.9475 - val_loss: 0.1353 - val_accuracy: 0.9435
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1237 - accuracy: 0.9507 - val_loss: 0.1288 - val_accuracy: 0.9468
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 877us/step - loss: 0.1148 - accuracy: 0.9540
# Metric  loss : 0.11
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
 batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-250-250-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=250, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=250, activation="relu",name='second_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.2121 - accuracy: 0.9143 - val_loss: 0.1409 - val_accuracy: 0.9421
# Epoch 2/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.1205 - accuracy: 0.9502 - val_loss: 0.1112 - val_accuracy: 0.9524
# Epoch 3/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.1035 - accuracy: 0.9570 - val_loss: 0.1092 - val_accuracy: 0.9531
# Epoch 4/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.0939 - accuracy: 0.9604 - val_loss: 0.1044 - val_accuracy: 0.9551
# Epoch 5/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.0923 - accuracy: 0.9607 - val_loss: 0.1006 - val_accuracy: 0.9565
# Epoch 6/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.0885 - accuracy: 0.9629 - val_loss: 0.1046 - val_accuracy: 0.9569
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 964us/step - loss: 0.0971 - accuracy: 0.9617
# Metric  loss : 0.1
# Metric  accuracy : 0.96

# %%
 history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-250-500-250-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=250, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=500, activation="relu",name='second_hidden'))
network.add(layers.Dense(units=250, activation="relu",name='third_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 5s 3ms/step - loss: 0.1984 - accuracy: 0.9203 - val_loss: 0.1167 - val_accuracy: 0.9534
# Epoch 2/10
# 1457/1457 [==============================] - 4s 3ms/step - loss: 0.1111 - accuracy: 0.9540 - val_loss: 0.1135 - val_accuracy: 0.9537
# Epoch 3/10
# 1457/1457 [==============================] - 4s 3ms/step - loss: 0.1003 - accuracy: 0.9586 - val_loss: 0.0987 - val_accuracy: 0.9583
# Epoch 4/10
# 1457/1457 [==============================] - 4s 3ms/step - loss: 0.0961 - accuracy: 0.9607 - val_loss: 0.0969 - val_accuracy: 0.9591
# Epoch 5/10
# 1457/1457 [==============================] - 4s 3ms/step - loss: 0.0938 - accuracy: 0.9622 - val_loss: 0.0981 - val_accuracy: 0.9590
# Epoch 6/10
# 1457/1457 [==============================] - 4s 3ms/step - loss: 0.0903 - accuracy: 0.9631 - val_loss: 0.1009 - val_accuracy: 0.9566
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 1ms/step - loss: 0.1082 - accuracy: 0.9620
# Metric  loss : 0.11
# Metric  accuracy : 0.96

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreza 22-1000-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=1000, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.2260 - accuracy: 0.9112 - val_loss: 0.1506 - val_accuracy: 0.9370
# Epoch 2/10
# 1457/1457 [==============================] - 2s 2ms/step - loss: 0.1416 - accuracy: 0.9429 - val_loss: 0.1406 - val_accuracy: 0.9415
# Epoch 3/10
# 1457/1457 [==============================] - 2s 2ms/step - loss: 0.1187 - accuracy: 0.9518 - val_loss: 0.1286 - val_accuracy: 0.9459
# Epoch 4/10
# 1457/1457 [==============================] - 3s 2ms/step - loss: 0.1089 - accuracy: 0.9553 - val_loss: 0.1113 - val_accuracy: 0.9501
# Epoch 5/10
# 1457/1457 [==============================] - 2s 2ms/step - loss: 0.1046 - accuracy: 0.9557 - val_loss: 0.1072 - val_accuracy: 0.9525
# Epoch 6/10
# 1457/1457 [==============================] - 2s 2ms/step - loss: 0.1013 - accuracy: 0.9566 - val_loss: 0.1083 - val_accuracy: 0.9546
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 894us/step - loss: 0.0980 - accuracy: 0.9605
# Metric  loss : 0.1
# Metric  accuracy : 0.96

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Mreža 22-1000-1000-1000-1000-1000-1000-1

# %%
network = models.Sequential()


network.add(layers.Dense(units=1000, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=1000, activation="relu",name='second_hidden'))
network.add(layers.Dense(units=1000, activation="relu",name='third_hidden'))
network.add(layers.Dense(units=1000, activation="relu",name='fourth_hidden'))
network.add(layers.Dense(units=1000, activation="relu",name='fifth_hidden'))
network.add(layers.Dense(units=1000, activation="relu",name='sixth_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name='last'))

network.compile(loss="binary_crossentropy", # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 78s 53ms/step - loss: 0.2601 - accuracy: 0.9091 - val_loss: 0.1372 - val_accuracy: 0.9481
# Epoch 2/10
# 1457/1457 [==============================] - 82s 56ms/step - loss: 0.1315 - accuracy: 0.9515 - val_loss: 0.1309 - val_accuracy: 0.9498
# Epoch 3/10
# 1457/1457 [==============================] - 77s 53ms/step - loss: 0.1215 - accuracy: 0.9568 - val_loss: 0.1227 - val_accuracy: 0.9542
# Epoch 4/10
# 1457/1457 [==============================] - 76s 52ms/step - loss: 0.1128 - accuracy: 0.9580 - val_loss: 0.1247 - val_accuracy: 0.9552
# Epoch 5/10
# 1457/1457 [==============================] - 76s 52ms/step - loss: 0.1170 - accuracy: 0.9597 - val_loss: 0.1433 - val_accuracy: 0.9546
# Epoch 6/10
# 1457/1457 [==============================] - 77s 53ms/step - loss: 0.1230 - accuracy: 0.9600 - val_loss: 0.1266 - val_accuracy: 0.9582
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 6s 7ms/step - loss: 0.1947 - accuracy: 0.9559
# Metric  loss : 0.19
# Metric  accuracy : 0.96

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Kreiranje sopstvene loss funkcije

# %%
def my_loss(y_true, y_pred):
            
    loss = K.square(float(y_pred) - float(y_true))
    loss = loss *[0.3, 0.7]
    loss = K.sum(loss, axis=1)   
    return loss
  

network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name='first_hidden'))
network.add(layers.Dense(units=25, activation="relu",name='second_hidden'))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss=my_loss, # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 3s 1ms/step - loss: 0.1001 - accuracy: 0.8672 - val_loss: 0.0571 - val_accuracy: 0.9223
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0507 - accuracy: 0.9335 - val_loss: 0.0470 - val_accuracy: 0.9359
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0444 - accuracy: 0.9412 - val_loss: 0.0433 - val_accuracy: 0.9412
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0406 - accuracy: 0.9466 - val_loss: 0.0407 - val_accuracy: 0.9448
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0376 - accuracy: 0.9500 - val_loss: 0.0389 - val_accuracy: 0.9486
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0362 - accuracy: 0.9520 - val_loss: 0.0376 - val_accuracy: 0.9478
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 797us/step - loss: 0.0335 - accuracy: 0.9540
# Metric  loss : 0.03
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Kreiranje nove loss funkcije -- suprotno od njihovog odnosa obicna razlika

# %%
def my_loss(y_true, y_pred):
            
    loss = K.abs(float(y_pred) - float(y_true))
    loss = loss *[0.43, 0.56]
    loss = K.sum(loss, axis=1)   
    return loss
  

network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name="first_hidden"))
network.add(layers.Dense(units=25, activation="relu",name="second_hidden"))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss=my_loss, # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1861 - accuracy: 0.8408 - val_loss: 0.1021 - val_accuracy: 0.8990
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0910 - accuracy: 0.9104 - val_loss: 0.0877 - val_accuracy: 0.9131
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0779 - accuracy: 0.9235 - val_loss: 0.0773 - val_accuracy: 0.9244
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0695 - accuracy: 0.9321 - val_loss: 0.0716 - val_accuracy: 0.9300
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0668 - accuracy: 0.9344 - val_loss: 0.0670 - val_accuracy: 0.9344
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0605 - accuracy: 0.9407 - val_loss: 0.0649 - val_accuracy: 0.9356
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 924us/step - loss: 0.0585 - accuracy: 0.9414
# Metric  loss : 0.06
# Metric  accuracy : 0.94

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %%
def my_loss(y_true, y_pred):
            
    loss = K.square(float(y_pred) - float(y_true))
    loss = loss *[0.43, 0.56]
    loss = K.sum(loss, axis=1)   
    return loss
  

network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name="first_hidden"))
network.add(layers.Dense(units=25, activation="relu",name="second_hidden"))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss=my_loss, # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.1042 - accuracy: 0.8615 - val_loss: 0.0540 - val_accuracy: 0.9292
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0498 - accuracy: 0.9337 - val_loss: 0.0482 - val_accuracy: 0.9346
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0446 - accuracy: 0.9407 - val_loss: 0.0453 - val_accuracy: 0.9399
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0409 - accuracy: 0.9458 - val_loss: 0.0428 - val_accuracy: 0.9446
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0391 - accuracy: 0.9482 - val_loss: 0.0411 - val_accuracy: 0.9452
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0358 - accuracy: 0.9527 - val_loss: 0.0389 - val_accuracy: 0.9473
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 821us/step - loss: 0.0349 - accuracy: 0.9527
# Metric  loss : 0.03
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Sopstvena loss funkcija -- na osnovu odnosa zastupljenosti square

# %%
def my_loss(y_true, y_pred):
            
    loss = K.square(float(y_pred) - float(y_true))
    loss = loss *[0.56, 0.43]
    loss = K.sum(loss, axis=1)   
    return loss
  

network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name="first_hidden"))
network.add(layers.Dense(units=25, activation="relu",name="second_hidden"))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss=my_loss, # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0978 - accuracy: 0.8713 - val_loss: 0.0563 - val_accuracy: 0.9266
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0507 - accuracy: 0.9326 - val_loss: 0.0466 - val_accuracy: 0.9384
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0433 - accuracy: 0.9420 - val_loss: 0.0425 - val_accuracy: 0.9421
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0398 - accuracy: 0.9470 - val_loss: 0.0405 - val_accuracy: 0.9451
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 0.0378 - accuracy: 0.9500 - val_loss: 0.0380 - val_accuracy: 0.9486
# Epoch 6/10
# 1457/1457 [==============================] - -46809s -32149101us/step - loss: 0.0351 - accuracy: 0.9540 - val_loss: 0.0370 - val_accuracy: 0.9514
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 779us/step - loss: 0.0334 - accuracy: 0.9542
# Metric  loss : 0.03
# Metric  accuracy : 0.95

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ### Loss funkcija zasnovana na mean-u

# %%
def my_loss(y_true, y_pred):
            
    loss = K.square(float(y_pred) - float(K.mean(y_true)))
    loss = loss *[0.56, 0.43]
    loss = K.sum(loss, axis=1)   
    return loss
  

network = models.Sequential()


network.add(layers.Dense(units=25, activation="relu", input_shape=(22,),name="first_hidden"))
network.add(layers.Dense(units=25, activation="relu",name="second_hidden"))
network.add(layers.Dense(units=1, activation="sigmoid",name="output"))

network.compile(loss=my_loss, # Cross-entropy
 optimizer="rmsprop", 
 metrics=["accuracy"]) # Accuracy performance metric
keras.utils.plot_model(network, show_shapes=True)

# %%
network.fit(X_train, Y_train,
epochs=10, 
 verbose=1, # Print description after each epoch
 batch_size=64, # Number of observations per batch
 validation_data=(X_val, Y_val))
# Out:
# Epoch 1/10
# 1457/1457 [==============================] - 3s 1ms/step - loss: 0.0068 - accuracy: 0.5666 - val_loss: 4.5494e-10 - val_accuracy: 0.5734
# Epoch 2/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 4.9329e-10 - accuracy: 0.5667 - val_loss: 1.7411e-10 - val_accuracy: 0.5734
# Epoch 3/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 2.0751e-10 - accuracy: 0.5659 - val_loss: 1.0507e-10 - val_accuracy: 0.5734
# Epoch 4/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 1.0725e-10 - accuracy: 0.5664 - val_loss: 7.4550e-11 - val_accuracy: 0.5734
# Epoch 5/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 8.9587e-11 - accuracy: 0.5659 - val_loss: 5.7534e-11 - val_accuracy: 0.5734
# Epoch 6/10
# 1457/1457 [==============================] - 2s 1ms/step - loss: 6.6386e-11 - accuracy: 0.5651 - val_loss: 4.6713e-11 - val_accuracy: 0.5734
# Epoch 7/10
# ...

# %%
result = network.evaluate(X_test,Y_test)
for i in range(len(network.metrics_names)):
 print("Metric ",network.metrics_names[i],":",
str(round(result[i],2)))
# Out:
# 810/810 [==============================] - 1s 742us/step - loss: 4.5842e-11 - accuracy: 0.5611
# Metric  loss : 0.0
# Metric  accuracy : 0.56

# %%
history=network.fit(X_train, Y_train,
epochs=10, 
 verbose=0,
    batch_size=64,
 validation_data=(X_val, Y_val))

training_loss = history.history["loss"]
test_loss = history.history["val_loss"]

epoch_count = range(1, len(training_loss) + 1)


plt.plot(epoch_count, training_loss, "r--")
plt.plot(epoch_count, test_loss, "b-")
plt.legend(["Training Loss", "Test Loss"])
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.show();

training_acc=history.history['accuracy']
test_acc=history.history['val_accuracy']

plt.plot(training_acc)
plt.plot(test_acc)
plt.title("Model's Training & Validation Accuracy across epochs")
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# %% [markdown]
# ##  Zakljucak
# S obzirom da smo primetili ponovnim pregledom sajta kaggle da su ovi podaci vec ocisceni, shvatili smo zasto nije bilo previse posla u fazi deskriptivne analize i preciscavanja podataka, dataset je sadrži poprilicno veliki broj instanci i već je podeljen u trening i test set, i zadovoljava okvirne uslove za treniranje neuronske mreže od oko 100 000 redova, takođe mora se napomenuti da su klase poprilično jednako zastupljene, te smo i očekivali da će se neuronska mreža dobro pokazati. Neuronska mreža je kreirana sa velikim brojem slojeva je prakticno isto performovala kao i ona sa manjim, nismo mogli doći do nekog overfitting-a koje je jako vidljivo, takođe pokušali smo da kreiramo neke sopstvene loss funkcije, od kojih se jedna jako loše pokazala dok su neke od njih dale poprilično dobre rezultate.
